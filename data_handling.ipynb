# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
rp = pd.read_csv("C:/Users/user/Desktop/BTS/Master/1st_Semester/Data Science Foundations/Session_1/BTS_MasterInBigData-master/Session_1/file_formats/rural_population_data.csv")

# %%
rp.head()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456

# %%
# 1. Find all unique values of the column “Continent”

rp["Continent"].unique()
# Out:
# array(['Africa', 'Asia', 'Oceania', 'Europe', 'North America',
#        'South America'], dtype=object)

# %%
# 2. Calculate a grow rate based on this formula: Growrate = (Population2100 - Population2000) / Population2000

growthrate = (rp["Population2010"] - rp["Population2000"]) / rp["Population2000"]
print(growthrate)
# Out:
# 0      0.267577
# 1      0.268056
# 2      0.247463
# 3      0.281308
# 4      0.249475
# 5      0.280155
# 6      0.229685
# 7      0.234645
# 8      0.260185
# 9      0.274044
# 10     0.234822
# 11     0.256058
# 12     0.241362
# 13     0.273337
# 14     0.244827
# 15     0.280551
# 16     0.246598
# 17     0.281330
# 18     0.267010
# 19     0.269164
# 20     0.097635
# 21     0.074335
# 22     0.114572
# 23     0.151014
# 24     0.118039
# 25     0.151791
# 26     0.065196
# 27     0.106578
# 28     0.122693
# 29     0.151823
#          ...
# 90    -0.082403
# 91     0.032857
# 92    -0.110450
# 93     0.021098
# 94    -0.119740
# 95     0.017181
# 96    -0.114631
# 97     0.019285
# 98    -0.010936
# 99     0.054624
# 100    0.101618
# 101    0.151736
# 102    0.098093
# 103    0.151726
# 104    0.098860
# 105    0.150712
# 106    0.101726
# 107    0.163235
# 108    0.099511
# 109    0.147775
# 110    0.097859
# 111    0.157440
# 112    0.094834
# 113    0.155762
# ...

# %%
# 3. Create a histogram of “Growrate”. 

plt.hist(growthrate)
plt.show()

# %%
# 4. Check the existence of NaN values in the DataFrame.

rp.isnull()
# Out:
#      Continent  ElevationZone  UrbanRuralDesignation  Population1990  \
# 0        False          False                  False           False
# 1        False          False                  False           False
# 2        False          False                  False           False
# 3        False          False                  False           False
# 4        False          False                  False           False
# 5        False          False                  False           False
# 6        False          False                  False           False
# 7        False          False                  False           False
# 8        False          False                  False           False
# 9        False          False                  False           False
# 10       False          False                  False           False
# 11       False          False                  False           False
# 12       False          False                  False           False
# ...

# %%
# 5. Find the average population size in the years 2000 and 2010.

np.mean((rp["Population2010"], rp["Population2000"]))
# Out:
# 128618904.92916666

# %%
# 6. Check how many rows have UrbanRuralDesignation equal to “Urban”.

len(rp["UrbanRuralDesignation"] == "Urban")
# Out:
# 120
